# %% [markdown]
# ### Experiment 1: Python Installation and starting with python

# %% [markdown]
# 2. Write Python programs to print strings in the given manner:
# a)   Hello Everyone !!!
# b)   Hello
# World
# c)   Hello
# World
# d) ‘ Rohit’ s date of birth is 12\05\1999’

# %%
print(" Hello Everyone !!!")
# Out:
#  Hello Everyone !!!

# %%
print(" Hello\nWorld")
# Out:
#  Hello
# World

# %%
print("""Hello
World""")
# Out:
# Hello
# World

# %%
print("' Rohit's date of birth is 12\\05\\1999'")
# Out:
# ' Rohit's date of birth is 12\05\1999'

# %% [markdown]
# 3. Declare a string variable called x and assign it the value “Hello”.
# Print out the value of x

# %%
x="Hello"
print(x)
# Out:
# Hello

# %% [markdown]
# 4. Take different data types and print values using print function.

# %%
a=10
b=1.0
c="hello"
print(a,b,c)
# Out:
# 10 1.0 hello

# %% [markdown]
# 5. Take two variables, a and b. Assign your first name and last name. Print your
# Name after adding your First name and Last name together.

# %%
x="Ayush"
y="Rawat"
print(x+" "+y)
# Out:
# Ayush Rawat

# %% [markdown]
# 6. Declare three variables, consisting of your first name, your last name and
# Nickname. Write a program that prints out your first name, then your nickname
# in parenthesis and then your last name.
# Example output: George (woody) Washington.

# %%
first_name = "George"
last_name = "Washington"
nickname = "woody"

print(first_name, "(" + nickname + ")", last_name)
# Out:
# George (woody) Washington

# %% [markdown]
# 7. Declare and assign values to suitable variables and print in the following way:
# NAME: NIKUNJ BANSAL
# SAP ID: 500069944
# DATE OF BIRTH: 13 Oct 1999
# ADDRESS: UPES
# Bidholi Campus
# Pincode: 248007
# Programme: AI & ML

# %%
Name="NAME:Ayush Rawat"
SAP_ID="SAP ID: 590020071"
DOB="DATE OF BIRTH:26/6/2006"
Addres="ADDRESS:UPES Bidholi Campus Pincode:248007 "
programme="core"
Semester="Semester: 2"
print(f"{Name}\n{SAP_ID}\n{DOB}\n{Addres}\n{programme}\n{Semester}")
# Out:
# NAME:Ayush Rawat
# SAP ID: 590020071
# DATE OF BIRTH:26/6/2006
# ADDRESS:UPES Bidholi Campus Pincode:248007
# core
# Semester: 2
