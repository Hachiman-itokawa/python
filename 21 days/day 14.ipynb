# %% [markdown]
# # Day 14

# %% [markdown]
# #### 1. Declare variables of different data types and print them in one line with labels.

# %%
a = 8
b = 5.9
c = "hello"
print("int:", a, "float:", b, "string:", c)

# %% [markdown]
# #### 2. Check whether a number is prime.

# %%
n = int(input("Enter a number: ") )
if n > 1:
    for i in range(2, n):
        if n % i == 0:
            print(f"{n} is not a prime number.")
            break
    else:
        print(f"{n} is a prime number.")
else:
    print(f"{n} is not a prime number.")

# %% [markdown]
# #### 3. Count vowels in a string.

# %%
s = input("Enter a string: " )
vowels = "aeiouAEIOU"
count = 0
for c in s:
    if c in vowels:
        count += 1
print(f"The number of vowels in the string is: {count}")

# %% [markdown]
# #### 4.Remove duplicates using set.

# %%
lst = [1, 2, 2, 3, 4, 4]
unique = list(set(lst))
print("Unique elements:", unique)

# %% [markdown]
# #### 5. Find average of elements in a tuple.

# %%
t = (10, 20, 30, 40)
avg = sum(t) / len(t)
print("Average =", avg)

# %% [markdown]
# #### 6. Add elements to a set.

# %%
s = {10, 20, 30, 40}
n = int(input("Enter a number: ") )
s.add(n)
print(s)

# %% [markdown]
# #### 7. Write a function to return multiple values (sum & average).

# %%
def sum_and_average(lst):
    total = sum(lst)
    average = total / len(lst)
    return total, average
lst = [int(x) for x in input("Enter numbers with space: " ).split()]
total, average = sum_and_average(lst)
print("Total =", total)
print("Average =", average)

# %% [markdown]
# #### 8. Find largest number in list using a function (no max).

# %%
# +code
def largest_list(lst):
    if not lst:
        return None
    max_val = lst[0]
    for x in lst:
        if x > max_val:
            max_val = x
    return max_val
numbers = [int(x) for x in input("Enter numbers with space: " ).split()]
print("Largest number:", largest_list(numbers))

# %% [markdown]
# #### 9. Take a number and print all its factors.

# %%
n = int(input("Enter a number: ") )
for i in range(1, n + 1):
    if n % i == 0:
        print(i, end=" ")

# %% [markdown]
# #### 10. Check if a number is a perfect number.

# %%
n = int(input("Enter a number: ") )
divisors = [i for i in range(1, n) if n % i == 0]
if sum(divisors) == n:
    print(f"{n} is a perfect number.")
else:
    print(f"{n} is not a perfect number.")
