# %% [markdown]
# # TEST 4/22/2026

# %%
#Q1
class STUDENT:
    school_name="UPES"

    def __init__(self,name,age):
        self.name=name
        self.age=age
stu1=STUDENT("AMAN", 20)
stu2=STUDENT("RIYA", 21)

print(STUDENT.school_name)
print(stu1.school_name)
print(stu2.school_name)
# Out:
# UPES
# UPES
# UPES

# %%
#Q2

class Employee:
    company="ABC Ltd"

    def __init__(self,name,salary):
        self.name=name
        self.salary=salary

def show_details(self):
    print(f"Employee: {self.name}, Salary: {self.salary}, Company: {Employee.company}")

@classmethod
def change_comapny(cls,new_name):
    cls.companny=new_name

employee1=Employee("aman",50000)
employee2=Employee("jriya",60000)

print("change before:")

employee1.show_details()
employee2.show_details()

Employee.change_comapny("XYZ Ltd")

print("change after")

employee1.show_details()
employee2.show_details()
# Out:
# change before:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 28
#      24 employee2=Employee("jriya",60000)
#      26 print("change before:")
# ---> 28 employee1.show_details()
#      29 employee2.show_details()
#      31 Employee.change_comapny("XYZ Ltd")
#
# AttributeError: 'Employee' object has no attribute 'show_details'

# %%
#Q3
class MAthHelper:
    @staticmethod
    def is_even(num):
        return num%2==0
    
print(MAthHelper.is_even(8))
print(MAthHelper.is_even(11))
# Out:
# True
# False
