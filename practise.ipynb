# %%
h="hello"
w="world"
print(f"{h} {w} ")
# Out:
# hello world

# %%
h="hello"
print("", h)
# Out:
#  hello

# %%
print("hello world")
# Out:
# hello world

# %%
name="khuchisake"
print(f"{name} hello"  )
# Out:
# khuchisake hello

# %%
a=10
b=2
print("%d number" %(a*b))
# Out:
# 20 number

# %%
print("my name is 'nagraj'" 
 "really" )
# Out:
# my name is 'nagraj'really

# %%
a,b="2",3
txt="@"
print((a+" "+txt)*b)
# Out:
# 2 @2 @2 @

# %%
x = 3.14159

print(f"{x:.2f} value =")
# Out:
# 3.14 value =

# %%
x=3.31
b=32.1443
print("%.3f value is" %(x+b) )
# Out:
# 35.454 value is

# %%
a=1
print(type(a))
b=1.0
print(type(b))
c="bdhesg"
print(type(c))
d=None
print(type(d))
e=True
print(type(e))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'NoneType'>
# <class 'bool'>

# %%
a=10
b=5
print(a//b)
# Out:
# 2

# %%
a="bfejbsi"
print=(a)
b=(4,4)
b[1]
# Out:
# 4

# %%
a=1
b=-5
sum=a%b
print(sum)
type(sum)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 4
#       2 b=-5
#       3 sum=a%b
# ----> 4 print(sum)
#       5 type(sum)
#
# TypeError: 'str' object is not callable

# %%
a=int(input("first number: "))
b=int(input("second number: "))
print(a+b)
# Out:
# 108

# %%
a=int(input("side of square:"))
print("area of sqaure: ", a*a)
# Out:
# area of sqaure:  16

# %%
a=int(input("first number: "))
b=int(input("second number: "))
print("%d" %(a+b))
print("%d" %(a-b))
print("%d" %(a*b))
print("%d" %(a//b))
# Out:
# 18
# 2
# 80
# 1

# %%
a=int(input("age:"))
if a<18:
    print("minor")
elif a>=18 and a<=100:
 print("adult")
else:
 print("invalid")
# Out:
# minor

# %%
food=input("is cake good for healt: ")
eat="unhygenic" if food == "yes" else "so u r either right or wrong"
print(eat)
# Out:
# unhygenic

# %%
food=input("vegetable or junk food: ")
print("nice") if food == "vegetable" else print("unhygenic")
# Out:
# unhygenic

# %%
a=2
b=3.2
c=str(b)
print(c*a)
# Out:
# 3.23.2

# %% [markdown]
# WAP to cheack if number entered by user is odd or even

# %%
a=int(input ("enter a number: "))
if(a%2==0):
    print("even no")
else:
    print("odd no")
# Out:
# odd no

# %%
# syntax (false statment, true sta) [condition]
age=int(input("age: "))
vote=("no", "yes") [age>=18]
print("", vote)
# Out:
#  no

# %%
a=int("2")
print(a+3)
# Out:
# 5

# %%
a=2
b=5
print((a==b)+1)
# Out:
# 1

# %%
a="hifsrfrr"
b="\thifsrfrr"
print(a[3])
print(a+b)
# Out:
# s
# hifsrfrr	hifsrfrr

# %%
h="dsad"
h.capitalize()#capital first letter
# Out:
# 'Dsad'

# %%
h[2]
# Out:
# 'a'

# %%
hi="hiafsaf"
hi[-4:-1]#starting idnex:ending index:step
# Out:
# 'fsa'

# %%
hi="hiafsaf"
hi.endswith("f")
# Out:
# True

# %%
hi.find("s")
# Out:
# 4

# %%
hi.count("af")
# Out:
# 2

# %%
hi="hiafsaf"
hi.replace("hiafsaf","fsdefs")#replace which word,with which word
# Out:
# 'fsdefs'

# %%
len("hello")
# Out:
# 5

# %%
str="im coding"
str.capitalize()
# Out:
# 'Im coding'

# %%
a="i nt nt do"
a.count("do")
# Out:
# 1

# %%
a=int(input("age:"))
if(a>=18):
    if(a>=80):
        print("cannot drive")
    else:
        print("can drive")
else:
    print("error")
# Out:
# can drive

# %%
a=int(input("eneter a no:"))
b=int(input("eneter a no:"))
c=int(input("eneter a no:"))

if(a>b and a>c):
    print("a is greater no", a)
elif(b>a and b>c):
    print("b is greater no", b)
elif(c>a and c>b):
    print("c is greater no", c)
# Out:
# c is greater no 8

# %%
Marks=[21,23,34,23,43]
Marks[1]=21
Marks[0:4:2]
# Out:
# [21, 34]

# %%
Marks.append(35)
Marks
# Out:
# [21, 21, 34, 23, 43, 35]

# %%
Marks.sort()
Marks
# Out:
# [21, 21, 23, 34, 35, 35, 43]

# %%
Marks.sort(reverse=True)#sorts in decending
Marks
# Out:
# [43, 35, 35, 34, 23, 21, 21]

# %%
Marks.reverse()
Marks
# Out:
# [35, 43, 23, 34, 21, 21]

# %%
Marks.insert(1,2)#insert at value base on location (idx,val)
Marks
# Out:
# [35, 2, 43, 23, 34, 21, 21]

# %%
hi[1]
# Out:
# 'i'

# %%
hi[0]=24#can change at location
hi
# Out:
# [24, 262, 53, 23, 32, 43]

# %%
hi.insert(5,21)
hi
# Out:
# [21, 23, 262, 53, 23, 21, 32, 43]

# %%
hi.remove(262)
hi
# Out:
# [21, 23, 53, 23, 21, 32, 43]

# %%
hi.pop(3) #rem value at idx
hi
# Out:
# [21, 23, 53, 21, 32, 43]

# %%
tup=(2,1,4,1)
tup.index(1)#find val at which idx
# Out:
# 1

# %%
tup[1]
# Out:
# 1

# %%
tup.count(1)
# Out:
# 2

# %%
"PyThOn".swapcase()
# Out:
# 'pYtHoN'

# %%
sorted.__doc__
# Out:
# 'Return a new list containing all items from the iterable in ascending order.\n\nA custom key function can be supplied to customize the sort order, and the\nreverse flag can be set to request the result in descending order.'

# %%
print("python"[::])
# Out:
# python

# %%
a, b = 6, 3
print("a << 5 =", a << 5)
# Out:
# a << 5 = 192

# %%
a=input("enter a first fav movie:")
b=input("enter a sec fav movie:")
c=input("enter a third fav movie:")

l=[a,b,c]
print(l)
# Out:
# ['spiderman', 'iron man', 'anime']

# %%
dic={
    "name": "nothing",
    "subject" : "BCA",
    "langauge": "python",
    "maarks": {
        "phy": 97,
        "chem": 85,
    },
    "age": 19,
}
dic["name"]="hi"
print(dic["name"])
dic[21]="hello"
print(dic)
# Out:
# hi
# {'name': 'hi', 'subject': 'BCA', 'langauge': 'python', 'maarks': {'phy': 97, 'chem': 85}, 'age': 19, 21: 'hello'}

# %%
dic["langauge"]
# Out:
# 'python'

# %%
print(dic["maarks"]["chem"])
# Out:
# 85

# %%
len(dic["maarks"])
# Out:
# 2

# %%
dic.keys()#give dic keys
# Out:
# dict_keys(['name', 'subject', 'langauge', 'maarks', 'age', 21])

# %%
dic.values()
# Out:
# dict_values(['hi', 'BCA', 'python', {'phy': 97, 'chem': 85}, 19, 'hello'])

# %%
p=list(dic.items())# return all key and values
p[0]
# Out:
# ('name', 'hi')

# %%
dic.items()
# Out:
# dict_items([('name', 'hi'), ('subject', 'BCA'), ('langauge', 'python'), ('maarks', {'phy': 97, 'chem': 85}), ('age', 19), (21, 'hello')])

# %%
dic.get("langauge")
# Out:
# 'python'

# %%
#print(dic["name2"]) #it gives error
print(dic.get("name2"))
# Out:
# None

# %%
dic.update({"delhi" : "700aqi"})
dic
# Out:
# {'name': 'hi',
#  'subject': 'BCA',
#  'langauge': 'python',
#  'maarks': {'phy': 97, 'chem': 85},
#  'age': 19,
#  21: 'hello',
#  'delhi': '700aqi'}

# %%
set={1,2,3,4,5,5,5}
print(set)
# Out:
# {1, 2, 3, 4, 5}

# %%
type(set)
# Out:
# set

# %%
set.add(8)
set
# Out:
# {1, 2, 3, 4, 5, 8}

# %%
set.remove(5)
set
# Out:
# {1, 2, 3, 4, 8}

# %%
strin_set={"hello","hi","bye","idk"}
strin_set.pop()
strin_set #remove any random val
# Out:
# {'bye', 'hi', 'idk'}

# %%
a=()
type(a)
# Out:
# tuple

# %%
strin_set.clear()#clear all set

# %% [markdown]
# SET METHOD

# %%
set1={2,3,6,4,8,21,32}
set2={3,5,4,21,54,34}
set1.intersection(set2)
# Out:
# {3, 4, 21}

# %%
set1.union(set2)
# Out:
# {2, 3, 4, 5, 6, 8, 21, 32, 34, 54}

# %%
empty_dict={}
a=input("enter subject 1:")
b=input("enter subject 2:")
c=input("enter subject 3:")
x=int(input("enter marks of subject 1:"))
y=int(input("enter marks of subject 2:"))
z=int(input("enter marks of subject 3:"))
empty_dict.update({
    a:x,
    b:y,
    c:z,
})
print(empty_dict)
# Out:
# {'phy': 34, 'vhem': 34, 'math': 23}

# %%
count=5
while count >= 1:
    print(count)
    count -= 1
# Out:
# 5
# 4
# 3
# 2
# 1

# %%
i=1
while i<=9:
    print("hello")
    i+=1
# Out:
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello

# %%
i=7
while i>=1:
    print(i)
    if(i==4):
        break
    i-=1
# Out:
# 7
# 6
# 5
# 4

# %%
i=10
while i>=1:
    print(4*i)
    i-=1
# Out:
# 40
# 36
# 32
# 28
# 24
# 20
# 16
# 12
# 8
# 4

# %%
n=[1,4,9,16,25,36,49,64,81,100]
idx=0
while idx<len(n):
    print(n[idx])
    idx+=1
# Out:
# 1
# 4
# 9
# 16
# 25
# 36
# 49
# 64
# 81
# 100
# list

# %%
n=[1,4,9,16,25,36,49,64,81,100]
for el in n:
    print(el)
# Out:
# 1
# 4
# 9
# 16
# 25
# 36
# 49
# 64
# 81
# 100

# %%
x=int(input("enter a number: "))
i=0
while i<len(n):
    if(n[i]==x):
        print("found ",i)
    else:
        print("not found")
    i+=1
# Out:
# not found
# found  1
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found

# %%
i=0
while i<=5:
    if(i==3):
        i+=1
        continue
    print(i)
    i+=1
# Out:
# 0
# 1
# 2
# 4
# 5

# %%
for el in n:
    if(el==4):
        continue
    print(el)
else:
    print("loop end")
# Out:
# 1
# 9
# 16
# 25
# 36
# 49
# 64
# 81
# 100
# loop end

# %%
n=int(input("enter a no"))
i=0
sum=0
while i<=n:
    sum+=i
    i+=1
print("",sum)
# Out:
#  15

# %%
n=int(input("enter a no"))
multiply=1
for el in range(1,n+1):
    multiply*=el
print("",multiply)
# Out:
#  720

# %%
for el,le in enumerate (n):
    print(el,le)
# Out:
# 0 1
# 1 2
# 2 3
# 3 4
# 4 5

# %%
t=(1,4,9,16,25,36,49,64,81,100)
x=int(input("enter a no:"))
for el,idx in enumerate(t):
    if(idx == x):
        print("found at ",el)
        idx+=1
# Out:
# found at  3

# %%
for el in range(1,10,2):
    print(el)
# Out:
# 1
# 3
# 5
# 7
# 9

# %%
arr = [10, 20, 30]
for i in range(len(arr)):
    print(i, arr[i])
# Out:
# 0 10
# 1 20
# 2 30

# %%
student=["a","b",'c']
marks=[90,80,75]

for stu,ma in zip(student,marks):
   print(stu,ma)
# Out:
# a 90
# b 80
# c 75

# %%
for i in range(1, 4):
    for j in range(1, 3):
        print(i, j)
# Out:
# 1 1
# 1 2
# 2 1
# 2 2
# 3 1
# 3 2

# %%
n=int(input("enter a number: "))
for el in range(1,11):
    print=(el * n)

# %%
def calc_sum(a,b):
    return a+b

a=int(input("enter a number"))
b=int(input("enter a number"))
print(calc_sum(a,b))
a=int(input("enter a number"))
b=int(input("enter a number"))
print(calc_sum(a,b))
# Out:
# 9
# 24

# %%
def  cal_sum(e,d):
    return e+d,e-d

e=int(input("enter a number"))
d=int(input("enter a number"))
print(cal_sum(e,d))
# Out:
# (53, 11)

# %%
def p():
     print("hello world")

p()
p()
# Out:
# hello world
# hello world

# %%
out=p()
print(out)
# Out:
# hello world
# None

# %%
def avearge(a,b,d):
    return (a+b+d)/3
a=int(input("enter a number"))
b=int(input("enter a number"))
d=int(input("enter a number"))
avearge(a,b,d)
# Out:
# 22.0

# %%
def mul(a=1,b=4):
    return a*b

mul()
# Out:
# 4

# %%
def fact(n):
    m=1
    for el in range(1,n+1):
        m*=el
    print(m)

n=int(input("enter a no:"))
fact(n)
# Out:
# 120

# %%
def odd_even(a):
    if(a%2==0):
        print("no is even")
    else:
        print("no is odd")

a=int(input("enter a number"))
odd_even(a)
a=int(input("enter a number"))
odd_even(a)
# Out:
# no is odd
# no is odd

# %%
def show(n):
    if(n==15):
       return
    print("hello")
    print("end")
    show(n+1)

show(10)
# Out:
# hello
# end
# hello
# end
# hello
# end
# hello
# end
# hello
# end

# %%
def fact(n):
    if(n ==0 or n==1):
        return 1 
    return 3 * fact(3-1)

t=fact(3)
print(t)
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# Cell In[19], line 6
#       3         return
#       4     return 3 * fact(3-1)
# ----> 6 t=fact(3)
#       7 print(t)
#
# Cell In[19], line 4, in fact(n)
#       2 if(n ==0 or n==1):
#       3     return
# ----> 4 return 3 * fact(3-1)
#
# Cell In[19], line 4, in fact(n)
#       2 if(n ==0 or n==1):
#       3     return
# ----> 4 return 3 * fact(3-1)
#
#     [... skipping similar frames: fact at line 4 (2974 times)]
#
# Cell In[19], line 4, in fact(n)
#       2 if(n ==0 or n==1):
#       3     return
# ----> 4 return 3 * fact(3-1)
#
# RecursionError: maximum recursion depth exceeded
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ...

# %%
def add(*nums):
    print(nums)
add(1, 2, 3, 4)
# Out:
# (1, 2, 3, 4)

# %%
def info(**data):
    print(data)

info(name="Rahul", age=20)
# Out:
# {'name': 'Rahul', 'age': 20}

# %%
def area_circle(r):
    """Return area of circle for radius r."""
    return 3.14159 * r * r

area_circle.__doc__
# Out:
# 'Return area of circle for radius r.'

# %%
square = lambda x: x*x
x=int(input("enter a number"))
print(square(x))
# Out:
# 36

# %%
max_num = lambda a, b: a if a > b else b
a=int(input("enter a number"))
b=int(input("enter a number"))
print(max_num(a, b))
# Out:
# 6

# %%
def square(x):
    return x*x

nums = [1, 2, 3, 4]

result = list(map(square, nums))
print(result)
# Out:
# [1, 4, 9, 16]

# %%
nums = [1,2,3,]
list(map(lambda x: x*2, nums))
# Out:
# [2, 4, 6]

# %%
list(filter(lambda x: x%2==1, nums))
# Out:
# [1, 3]

# %%
def outer():
    def inner():
        print("Hello")

    inner()

outer()
# Out:
# Hello

# %%
class student:
    def __init__(self, name, age, marks):
        self.name = name
        self.age = age
        self.marks = marks
def to_json(obj):
    if isinstance(obj, (str, int, float, bool)) or obj is None:
        return repr(obj)
    elif isinstance(obj, list):
        return '[' + ', '.join(to_json(item) for item in obj) + ']'
    elif isinstance(obj, dict):
        items = []
        for key, value in obj.items():
            items.append(f"{repr(key)}: {to_json(value)}")
        return '{' + ', '.join(items) + '}'
    else:
        raise TypeError(f"Type {type(obj)} not supported")
s = student("hello", 20, [85, 90, 95])
print(to_json(s.__dict__))
s2 = student("bam", 22, [80, 85, 90])
print(to_json(s2.__dict__))
s3 = student("Cj", 19, [90, 92, 88])
print(to_json(s3.__dict__))
# Out:
# {'name': 'hello', 'age': 20, 'marks': [85, 90, 95]}
# {'name': 'bam', 'age': 22, 'marks': [80, 85, 90]}
# {'name': 'Cj', 'age': 19, 'marks': [90, 92, 88]}
