# %% [markdown]
# # 1/21/2026

# %%
" hello world "
# Out:
# ' hello world '

# %%
"  hello".lstrip()
# Out:
# 'hello'

# %%
"hello  ".rstrip()
# Out:
# 'hello'

# %%
"hello hell".find("ll")
# Out:
# 2
